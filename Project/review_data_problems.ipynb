# %%
run audit_islamabad.py

filepath = os.path.abspath("C:/Users/Saad Khalid/Downloads/islamabad_pakistan.osm")

# %%
## printing unique phone numbers found in the osm file
print_phones(filepath)
# Out:
# +92 992 330376
# +92-51-111901901
# +92 51-2852024
# +92 51 8445544
# 009251 8313 200, 5766380, 559 0063
# +92-992-383591
# +92512277117
# +92 322 5010051
# 051-4438559/51-5839323
# +92 51 8466 5323
# +92-51-8319000
# 00923005205536
# +92 51 2821093
# +92 51 2609301
# +92 51 287 2639
# +92512580479
# +92 336 5060655
# 92544711275
# 0515500077
# +92 51 2820304
# +92 51 843 8085
# +92 333 4861232
# +92 51335570034
# +92 51 2872639
# +92 333 4861234
# +92 51 3510883
# +92 51 227 8896
# 111-722-722
# Office 057-2612576 / Office 057-2602357 /Cell Phone 0300-5529121/  Cell Phone 0333-5534805
# +92-513-592066, 0308-3878787,0320-5000666
# +92-51-4917311
# +92512650953
# 051-2851267
# 92544710722
# +92 992 332721
# +92 57 2703577
# 0515738430
# +92 51 2104054
# +92 51 2203064
# +92 51 227 1545
# 03335120845

# %%
## printing unique postcodes found in the osm file
print_postcodes(filepath)
# Out:
# 10530
# 46060
# 22010
# 46000
# 44000
# 4600
# 46600

# %%
## printing unique street addresses found in the osm files
print_street_addresses(filepath)
# Out:
# Street No. 24
# Lane-2
# Lane-1
# Lane 8 A, Sector H
# Lane-4
# Daulatala Road
# College Road, Street 16, F-7/2
# Cantt
# Massy Gate
# Street No1
# Railway Road S
# Street 43
# 27
# Street 47
# 22
# Street 48
# Street 49
# GT ROAD
# Airport Road
# Streety 26
# Streety 27
# Streety 25
# 4
# Mardan - Swabi Rd
# Street # 13, Dhoke Kashmirian
# College Road, F-7
# 3
# Bank Road, Canning Road
# Street 19, F-6/2
# 122
# 123
# 124
# Jinnah Road
# 128
# Tulsa Road
# 26, F-6/2
# Daulatala Rd
# Housing Scheme No.1
# 55
# Lake View Park
# Circular Road
# Street 78
# Risalat Ma'Ab Road
# 57
# 16, F-7
# 124A
# 6th road
# National Park Road
# Street 154
# Street 60
# Street 61
# Street 62
# Tipu Road
# Asghar Mall Road
# School Road
# Fazle-Haq Road
# Kallar Syedan - Thoha Road
# Nazim ud Din Road
# Bucha Service Road
# Tipu Sultan Road
# Lalarukh Colony Road
# Link
# Ghazi kot Road
# Sukho Gujar Khan Road
# Mandra Chakwal Road
# Ibn-e-Sina Road
# Street 19
# Street 18
# Sitara Market
# Street 15
# ...
